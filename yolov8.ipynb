# %%
# !nvidia-smi
# Out:
# Thu Mar 20 04:27:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/my project/Traffic-Sign-2" "/content/"

# %%
# !cp -r "/content/drive/MyDrive/my project/new runs" "/content/"

# %%
#import shutil

#Replace 'folder_path' with the path to the folder you want to delete
#folder_path = '/content/runs'  # Example: '/content/drive/MyDrive/folder_to_delete'
#shutil.rmtree(folder_path)
#print(f"Folder {folder_path} deleted successfully!")
# Out:
# Folder /content/runs deleted successfully!

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 41.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo task=detect mode=train model="/content/drive/MyDrive/my project/YOLOV8 RESULTS (WITH AUGMENTATION)/train/weights/best.pt" data=/content/Traffic-Sign-2/data.yaml epochs=100 imgsz=640 project="/content/drive/MyDrive/my project/yolov8n + augmentation (200ep)"
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
Image(filename= f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
import shutil

# %%
shutil.move('/content/runs','/content/drive/MyDrive/my project/new runs 4')
# Out:
# '/content/drive/MyDrive/my project/new runs 4'

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/my project/new runs 5/runs/detect/train/weights/best.pt")  # Load a pre-trained YOLO model
results = model.val(data="/content/Traffic-Sign-2/data.yaml")  # Validate on dataset
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 3,013,058 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/my project/Traffic-Sign-2/valid/labels.cache... 928 images, 0 backgrounds, 0 corrupt: 100%|██████████| 928/928 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 58/58 [00:15<00:00,  3.84it/s]
#                    all        928        972      0.794      0.737       0.79      0.676
#               bus_stop          2          2          1          0    0.00424    0.00424
#           do_not_enter         31         31      0.902      0.903      0.921      0.852
#            do_not_stop         31         31      0.702      0.903      0.851      0.789
#          do_not_turn_l         31         35      0.934      0.971      0.976      0.869
# ...

# %%
from ultralytics import YOLO

#load a model
model = YOLO('/content/best.pt')

#export the model
model.export(format='tflite')
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,013,058 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 42, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'onnx>=1.12.0', 'onnx2tf>1.17.5,<=1.26.3', 'onnxslim>=0.1.31', 'tflite_support', 'onnxruntime'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 283.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 202.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.6/445.6 kB 170.5 MB/s eta 0:00:00
# ...

# %%
import shutil
shutil.move("/content/best.onnx","/content/drive/MyDrive/my project")
# Out:
# '/content/drive/MyDrive/my project/best.onnx'
